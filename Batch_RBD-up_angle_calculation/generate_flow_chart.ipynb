# %%
from pyflowchart import Flowchart

with open('./PDB_preprocessor.py') as f:
    code = f.read()
fc = Flowchart.from_code(code)
print(fc.flowchart())
# Out:
# op2=>operation: from pymol import cmd
# op4=>operation: from pymol import stored
# op6=>operation: import pandas as pd
# op8=>operation: import numpy as np
# op10=>operation: from datetime import datetime
# op12=>operation: import time
# op14=>operation: from argparse import ArgumentParser
# st17=>start: start main
# io19=>inputoutput: input: pdbs_file
# op22=>operation: (wild, d614g, alpha, beta, gamma, delta, kappa, omicron, unknown_variant, potential_ace2_bound, not_trimeric, missing_chs) = ([], [], [], [], [], [], [], [], [], [], [], [])
# op24=>operation: with open(pdbs_file, 'r') as f:
#     for l in f:
#         pdbs = l.split(',')
# op26=>operation: with open(f'{datetime}_PDB_preprocess_log.txt', 'a') as f:
#     for code in pdbs:
#         print(f'''
# Loading {code} in PyMOL...''')
#         print(f'''
# Loading {code} in PyMOL...''', file=f)
#         cmd.load(f'{code}.cif', code)
#         print(f'''
# Check if the structure contains chain A/B/C...''')
# ...
